# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold, train_test_split
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# /content/drive/Shareddrives

# %%
data = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject39_1526417507/1526417507.csv', header = None)
data = data.T
data2 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject39_1526591202/1526591202.csv', header = None)
data2 = data2.T
data3 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject42_1527280030/1527280030.csv', header = None)
data3 = data3.T
data4 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject43_1527806941/1527806941.csv', header = None)
data4 = data4.T
data5 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject54_1539288817/1539288817.csv', header = None)
data5 = data5.T
data6 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject55_1539459892/1539459892.csv', header = None)
data6 = data6.T
train_data = pd.concat([data,data2,data3,data4,data5,data6],ignore_index = True)

# %%
data = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject39_1526417507/movementvalues.csv', header = None)
data = data.T
data = data.drop(0)
data2 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject39_1526591202/movementvalues.csv', header = None)
data2 = data2.T
data2 = data2.drop(0)
data3 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject42_1527280030/movementvalues.csv', header = None)
data3 = data3.T
data3 = data3.drop(0)
data4 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject43_1527806941/movementvalues.csv', header = None)
data4 = data4.T
data4 = data4.drop(0)
data5 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject54_1539288817/movementvalues.csv', header = None)
data5 = data5.T
data5 = data5.drop(0)
data6 = pd.read_csv('/content/drive/MyDrive/hackathon/ground_truth/Subject55_1539459892/movementvalues.csv', header = None)
data6 = data6.T
data6 = data6.drop(0)
target_values = pd.concat([data,data2,data3,data4,data5,data6],ignore_index = True)

# %%
class LSTM(nn.Module):
  def __init__(self, n_hidden = 512):
    super(LSTM, self).__init__()
    self.n_hidden = n_hidden
    self.lstm = nn.LSTM(input_size = 226, hidden_size = 512, batch_first = True)
    self.linear = nn.Linear(self.n_hidden, 3)

  def forward(self, x):
    h_t, c_t = self.lstm(x)
    h_t = h_t.squeeze()
    res = self.linear(h_t)
    res = res.T
    return res

# %%
class MovementDataset(torch.utils.data.Dataset):
  def __init__(self, train_data, targets = None):
    self.train_data = train_data
    self.targets = targets

  def __len__(self):
    return len(self.train_data)
  
  def __getitem__(self, idx):
    if self.targets is not None:
      try:
        train, targ = self.train_data.loc[idx], self.targets.loc[idx]
      except:
        train, targ = self.train_data.iloc[idx], self.targets.iloc[idx]
      train = train.values.reshape((1,len(train)))
      targ = targ.values.reshape((1,len(targ)))
      train = train.astype(np.float32)
      targ = targ.astype(np.float32)
      train = torch.tensor(train)
      targ = torch.tensor(targ)
      train = train.view((1, 240, 226))
      return train, targ
    else:
      try:
        train = self.train_data.loc[idx]
      except:
        train = self.train_data.iloc[idx]
      train = train.values.reshape((1,len(train)))
      train = train.astype(np.float32)
      train = torch.tensor(train)
      train = train.view((1, 240, 226))
      return train

# %%
traindata,validation =  train_test_split(train_data, test_size=0.16)

# %%
train_dataset = MovementDataset(traindata,target_values)
val_dataset = MovementDataset(validation, target_values)

# %%
train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size = 1)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size = 1)

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
def train(model, lossfn, optimizer, scheduler, device, epochs = 250):
    losses = []
    model.to(device)
    for i in range(epochs):
        model.train()
        print(f"Currently running epoch number {i+1}")
        for t, (xb, yb) in enumerate(train_dataloader):
            xb = xb.to(device, dtype = torch.float32)
            yb = yb.to(device, dtype = torch.int64)
            xb = xb.squeeze(0)
            yb = yb.squeeze()
            predictions = model(xb)
            predictions = predictions.T
            predictions = predictions.to(device, dtype = torch.float32)
            loss = lossfn(predictions, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            acc = torch.sum(torch.argmax(predictions, dim = 1) == yb)/len(yb)
        print(f"accuracy for train is {acc}")
        scheduler.step(loss)
        #print(f"Train loss for this epoch is {loss}")
        del loss,predictions
        
        with torch.no_grad():
          model.eval()
          for v, (xv, yv) in enumerate(val_dataloader):
            xv = xv.to(device, dtype = torch.float32)
            yv = yv.to(device, dtype = torch.int64)
            xv = xv.squeeze(0)
            yv = yv.squeeze()
            predictions = model(xv)
            predictions = predictions.T
            predictions = predictions.to(device, dtype = torch.float32)
            loss = lossfn(predictions, yv)
            acc = torch.sum(torch.argmax(predictions, dim = 1) == yv)/len(yv)
            print(f"accuracy for val is {acc}")
          #print(f"Val Loss for this epoch is {loss}")

# %%
model = LSTM()
lossfn = torch.nn.functional.cross_entropy
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode = 'min', patience = 7, verbose = True, eps = 1e-11)

# %%
train(model, lossfn, optimizer, scheduler, device)
# Out:
# Currently running epoch number 1
# accuracy for train is 0.5750000476837158
# accuracy for val is 0.9333333969116211
# Currently running epoch number 2
# accuracy for train is 0.6250000596046448
# accuracy for val is 0.9291667342185974
# Currently running epoch number 3
# accuracy for train is 0.6708333492279053
# accuracy for val is 0.9333333969116211
# Currently running epoch number 4
# accuracy for train is 0.6833333969116211
# accuracy for val is 0.9291667342185974
# Currently running epoch number 5
# accuracy for train is 0.6958333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 6
# accuracy for train is 0.7000000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 7
# accuracy for train is 0.7083333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 8
# accuracy for train is 0.7083333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 9
# accuracy for train is 0.7166666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 10
# accuracy for train is 0.7208333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 11
# accuracy for train is 0.7333333492279053
# accuracy for val is 0.9416667222976685
# Currently running epoch number 12
# accuracy for train is 0.7333333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 13
# accuracy for train is 0.737500011920929
# accuracy for val is 0.9458333849906921
# Currently running epoch number 14
# accuracy for train is 0.7291666865348816
# accuracy for val is 0.9416667222976685
# Currently running epoch number 15
# accuracy for train is 0.7333333492279053
# accuracy for val is 0.9416667222976685
# Currently running epoch number 16
# accuracy for train is 0.7416667342185974
# accuracy for val is 0.9416667222976685
# Currently running epoch number 17
# accuracy for train is 0.7416667342185974
# accuracy for val is 0.9416667222976685
# Currently running epoch number 18
# accuracy for train is 0.7291666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 19
# accuracy for train is 0.7458333969116211
# accuracy for val is 0.9416667222976685
# Currently running epoch number 20
# accuracy for train is 0.737500011920929
# accuracy for val is 0.9416667222976685
# Currently running epoch number 21
# accuracy for train is 0.7541667222976685
# accuracy for val is 0.9458333849906921
# Currently running epoch number 22
# accuracy for train is 0.7541667222976685
# accuracy for val is 0.9416667222976685
# Currently running epoch number 23
# accuracy for train is 0.7500000596046448
# accuracy for val is 0.9416667222976685
# Currently running epoch number 24
# accuracy for train is 0.7541667222976685
# accuracy for val is 0.9416667222976685
# Currently running epoch number 25
# accuracy for train is 0.7541667222976685
# accuracy for val is 0.9416667222976685
# Currently running epoch number 26
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 27
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 28
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 29
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 30
# accuracy for train is 0.7541667222976685
# accuracy for val is 0.9416667222976685
# Currently running epoch number 31
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 32
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 33
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 34
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 35
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9458333849906921
# Currently running epoch number 36
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 37
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9416667222976685
# Currently running epoch number 38
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 39
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 40
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9416667222976685
# Currently running epoch number 41
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9416667222976685
# Currently running epoch number 42
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9458333849906921
# Currently running epoch number 43
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9500000476837158
# Currently running epoch number 44
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9458333849906921
# Currently running epoch number 45
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 46
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9500000476837158
# Currently running epoch number 47
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9416667222976685
# Currently running epoch number 48
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9458333849906921
# Currently running epoch number 49
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9541667103767395
# Currently running epoch number 50
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9541667103767395
# Currently running epoch number 51
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9500000476837158
# Currently running epoch number 52
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9500000476837158
# Currently running epoch number 53
# accuracy for train is 0.7583333849906921
# accuracy for val is 0.9500000476837158
# Currently running epoch number 54
# accuracy for train is 0.7625000476837158
# Epoch    54: reducing learning rate of group 0 to 1.0000e-05.
# accuracy for val is 0.9541667103767395
# Currently running epoch number 55
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9541667103767395
# Currently running epoch number 56
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9541667103767395
# Currently running epoch number 57
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9541667103767395
# Currently running epoch number 58
# accuracy for train is 0.7625000476837158
# accuracy for val is 0.9541667103767395
# Currently running epoch number 59
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 60
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 61
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 62
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 63
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 64
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 65
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 66
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 67
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 68
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 69
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 70
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 71
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 72
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 73
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 74
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 75
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 76
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 77
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 78
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 79
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 80
# accuracy for train is 0.7666667103767395
# accuracy for val is 0.9541667103767395
# Currently running epoch number 81
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9541667103767395
# Currently running epoch number 82
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9541667103767395
# Currently running epoch number 83
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9541667103767395
# Currently running epoch number 84
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9541667103767395
# Currently running epoch number 85
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9541667103767395
# Currently running epoch number 86
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 87
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 88
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 89
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 90
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 91
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 92
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 93
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9500000476837158
# Currently running epoch number 94
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 95
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 96
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 97
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 98
# accuracy for train is 0.7708333730697632
# accuracy for val is 0.9458333849906921
# Currently running epoch number 99
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 100
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 101
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 102
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9500000476837158
# Currently running epoch number 103
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9500000476837158
# Currently running epoch number 104
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9500000476837158
# Currently running epoch number 105
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 106
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 107
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 108
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 109
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 110
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 111
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 112
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 113
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 114
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 115
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 116
# accuracy for train is 0.7750000357627869
# accuracy for val is 0.9458333849906921
# Currently running epoch number 117
# accuracy for train is 0.7791666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 118
# accuracy for train is 0.7791666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 119
# accuracy for train is 0.7791666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 120
# accuracy for train is 0.7791666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 121
# accuracy for train is 0.7791666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 122
# accuracy for train is 0.7791666984558105
# accuracy for val is 0.9458333849906921
# Currently running epoch number 123
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 124
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 125
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 126
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 127
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 128
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 129
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 130
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 131
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 132
# accuracy for train is 0.7833333611488342
# accuracy for val is 0.9458333849906921
# Currently running epoch number 133
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 134
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 135
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 136
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 137
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 138
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 139
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 140
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 141
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 142
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 143
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 144
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 145
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 146
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 147
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 148
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 149
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 150
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 151
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 152
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 153
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 154
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 155
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 156
# accuracy for train is 0.7875000238418579
# accuracy for val is 0.9458333849906921
# Currently running epoch number 157
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 158
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 159
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 160
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 161
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 162
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 163
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 164
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 165
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 166
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 167
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 168
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 169
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 170
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 171
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 172
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 173
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 174
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 175
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 176
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 177
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 178
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 179
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 180
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 181
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 182
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 183
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 184
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 185
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 186
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 187
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 188
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 189
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 190
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 191
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 192
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 193
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 194
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 195
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 196
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 197
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 198
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 199
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 200
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 201
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 202
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 203
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 204
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 205
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 206
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 207
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 208
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 209
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 210
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 211
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 212
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 213
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 214
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 215
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 216
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 217
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 218
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 219
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 220
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 221
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 222
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 223
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 224
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 225
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 226
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 227
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 228
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 229
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 230
# accuracy for train is 0.7916666865348816
# accuracy for val is 0.9458333849906921
# Currently running epoch number 231
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 232
# accuracy for train is 0.7958333492279053
# accuracy for val is 0.9458333849906921
# Currently running epoch number 233
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 234
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 235
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 236
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 237
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 238
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 239
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 240
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 241
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 242
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 243
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 244
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 245
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 246
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 247
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 248
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 249
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921
# Currently running epoch number 250
# accuracy for train is 0.8000000715255737
# accuracy for val is 0.9458333849906921

# %%
import os

# %%
df = pd.DataFrame()
addresses = []
for root, dir, files in os.walk('/content/drive/MyDrive/hackathon/dataset'):
  if files == []:
    pass
  else:
    path = os.path.join(root, files[0])
    data = pd.read_csv(path, header = None)
    addresses.append(root)    
    data = data.T
    df = pd.concat([df,data], ignore_index = True)

# %%
test_dataset = MovementDataset(df)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size = 1, shuffle = True)

# %%
with torch.no_grad():
        model.eval()
        for v, xv in enumerate(test_dataloader):
          xv = xv.to(device, dtype = torch.float32)
          xv = xv.squeeze(0)
          predictions = model(xv)
          predictions = torch.argmax(predictions, dim = 0)
          predictions = predictions.detach().cpu().numpy()
          path = addresses[v]
          time = int(path[-10:])
          timestamps = np.arange(time, time+240)
          predictionsdf = pd.DataFrame([timestamps,predictions])
          predictionsdf = predictionsdf.transpose()
          submission = predictionsdf.to_csv(os.path.join(path,'movementvalues.csv'), index = False, header = None)
